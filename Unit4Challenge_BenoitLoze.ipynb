# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 0. Table of content
# [1. Sourcing and Loading](#1.-Sourcing-and-Loading)
#   - [1.1. Importing Libraries](#1.1.-Importing-Libraries)
#   - [1.2. Loading the data](#1.2.-Loading-the-data)
#
# [2. Cleaning, transforming, and visualizing](#2.-Cleaning,-transforming,-and-visualizing)
#   - [2.1. Exploring your data](#2.1.-Exploring-your-data)
#   - [2.2. Cleaning the data](#2.2.-Cleaning-the-data)
#   - [2.3. Cleaning the data (part 2)](#2.3.-Cleaning-the-data-(part-2))
#   - [2.4. Transforming the data](#2.4.-Transforming-the-data)
#   - [2.5. Cleaning the data (part 3)](#2.5.-Cleaning-the-data-(part-3))
#   - [2.6. Visualizing the data](#2.6.-Visualizing-the-data)
#
# [3. Modeling](#3.-Modeling)

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2. Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
# properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# **Loading the data, browser simulation**
#
# The server (https://data.london.gov.uk) is blocking direct access via Python (HTTP Error 403: Forbidden).
# Simulating a browser request by setting a "User-Agent" header manually.

# %%
# Import of the request package:
import requests

# The URL of the Excel file
url = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# Simulate a browser by adding headers
headers = {'User-Agent': 'Mozilla/5.0'}

# Send request
response = requests.get(url, headers=headers)

# Save the content into a local file
with open('London_House_Prices.xls', 'wb') as file:
    file.write(response.content)

# Check:
print("File downloaded successfully!")
# Out:
# File downloaded successfully!

# %%
# loading it locally
properties = pd.read_excel('London_House_Prices.xls', sheet_name='Average price')

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# #### 2.1. Exploring your data
#
# Think about your pandas functions for checking out a dataframe.

# %% [markdown]
# ##### 2.1.1. Shape & display
#
# We explore the overall shape and display of the dataset.

# %%
# Shape (rows, columns) of the dataset:
properties.shape
# Out:
# (363, 49)

# %%
# Five first rows of the dataset:
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          90347              51870      98948      64956
# 2 1995-02-01          81213              52513      98848      64786
# 3 1995-03-01          78168              52701      97848      64366
# 4 1995-04-01          76172              54618      96273      64276
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1      76880      83082     119775      70118      85469  ...      40907
# 2      77651      83068     118365      69908      86551  ...      40877
# 3      77644      82856     119131      69666      87067  ...      41351
# 4      78668      82525     118948      69562      87933  ...      41195
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# ...

# %%
# Five last rows of the dataset:
properties.tail()
# Out:
#     Unnamed: 0 City of London Barking & Dagenham  Barnet  Bexley   Brent  \
# 358 2024-10-01         759401             342867  626302  408270  593866
# 359 2024-11-01         725572             354748  627685  405656  595358
# 360 2024-12-01         807642             354327  622984  404102  576148
# 361 2025-01-01         807469             353227  610940  405583  572675
# 362 2025-02-01         787104             363323  602832  408294  555173
#
#     Bromley  Camden Croydon  Ealing  ... NORTH WEST YORKS & THE HUMBER  \
# 358  506738  848261  409165  575648  ...     209008             202212
# 359  513197  854138  406392  574907  ...     211047             204616
# 360  512084  852044  408162  572169  ...     210380             204123
# 361  516472  838255  414069  579918  ...     210456             202277
# 362  517679  809827  411032  579736  ...     211977             205455
#
#     EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  LONDON SOUTH EAST SOUTH WEST  \
# ...

# %% [markdown]
# ##### 2.1.2. Cleanliness check
#
# With info()method, we check the presence and number of null values as well as the data type for each column.
# The methods .isna().sum() confirm the presence and number of null values in unnamed columns not in the Borough clolumns.
# The data type (Dtype) shows "object" for the price values which should nromally be "float".
# This means that either the data type is under "string" format or mixed format.

# %%
# Information on the dataset:
properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 363 entries, 0 to 362
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            362 non-null    datetime64[ns]
#  1   City of London        363 non-null    object
#  2   Barking & Dagenham    363 non-null    object
#  3   Barnet                363 non-null    object
#  4   Bexley                363 non-null    object
#  5   Brent                 363 non-null    object
#  6   Bromley               363 non-null    object
#  7   Camden                363 non-null    object
#  8   Croydon               363 non-null    object
#  9   Ealing                363 non-null    object
#  10  Enfield               363 non-null    object
#  11  Greenwich             363 non-null    object
#  12  Hackney               363 non-null    object
#  13  Hammersmith & Fulham  363 non-null    object
# ...

# %%
# Number of null value per column:
properties_null = properties.isna().sum()
properties_null[properties_null > 0]
# Out:
# Unnamed: 0       1
# Unnamed: 34    363
# Unnamed: 37    363
# Unnamed: 47    363
# dtype: int64

# %%
# List of columns with null values
columns_with_nulls = list(properties.columns[properties.isna().any()])
columns_with_nulls
# Out:
# ['Unnamed: 0', 'Unnamed: 34', 'Unnamed: 37', 'Unnamed: 47']

# %% [markdown]
# #### 2.2. Cleaning the data
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %% [markdown]
# ##### 2.2.1. Null data cleaning

# %% [markdown]
# ###### 2.2.1.1. Null row
# The entire row does not contain relevant information in regard to the object of the dataset.
# Therefore, it can be dropped.

# %%
properties[properties['Unnamed: 0'].isnull() == True]
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# 0          E12000003     E12000004     E12000005       E12000006  E12000007
#
#   SOUTH EAST SOUTH WEST Unnamed: 47    England
# 0  E12000008  E12000009         NaN  E92000001
#
# [1 rows x 49 columns]

# %%
null_row_index = properties[properties['Unnamed: 0'].isnull() == True].index
null_row_index
# Out:
# Index([0], dtype='int64')

# %%
properties = properties.drop(null_row_index)
properties.shape
# Out:
# (362, 49)

# %% [markdown]
# ###### 2.2.1.2. Null columns:
# 'Unnamed: 34', 'Unnamed: 37', 'Unnamed: 47' colums contain 363 null values, which makes them irrelevant to the object of the dataset.
# Therefore, they can be dropped.

# %%
columns_with_nulls.pop(0)
# Out:
# 'Unnamed: 0'

# %%
properties = properties.drop(columns_with_nulls, axis=1)

# %%
properties.shape
# Out:
# (362, 46)

# %% [markdown]
# ##### 2.2.2. Relevant data to the 32 Boroughs of London:
# "City of London" is not conisdered as a London Borough.
# Likewise, "Inner London", "Outer London" and all other England-related information are not relevant to the object of the dataset.
# Should remain the date column and the 32 London borough columns (e.g.: 33 columns).

# %%
properties_columns = list(properties.columns)
properties_columns
# Out:
# ['Unnamed: 0',
#  'City of London',
#  'Barking & Dagenham',
#  'Barnet',
#  'Bexley',
#  'Brent',
#  'Bromley',
#  'Camden',
#  'Croydon',
#  'Ealing',
#  'Enfield',
#  'Greenwich',
#  'Hackney',
#  'Hammersmith & Fulham',
#  'Haringey',
#  'Harrow',
#  'Havering',
#  'Hillingdon',
#  'Hounslow',
#  'Islington',
#  'Kensington & Chelsea',
#  'Kingston upon Thames',
#  'Lambeth',
#  'Lewisham',
#  'Merton',
#  'Newham',
#  'Redbridge',
#  'Richmond upon Thames',
#  'Southwark',
#  'Sutton',
#  'Tower Hamlets',
#  'Waltham Forest',
#  'Wandsworth',
#  'Westminster',
#  'Inner London',
#  'Outer London',
#  'NORTH EAST',
#  'NORTH WEST',
#  'YORKS & THE HUMBER',
#  'EAST MIDLANDS',
#  'WEST MIDLANDS',
#  'EAST OF ENGLAND',
#  'LONDON',
#  'SOUTH EAST',
#  'SOUTH WEST',
#  'England']

# %%
properties_columns_to_be_removed = []
properties_columns_to_be_removed.append(properties_columns.pop(1))

# %%
index_start = properties_columns.index('Inner London')
index_start
# Out:
# 33

# %%
properties_columns_to_be_removed.extend(properties_columns[index_start:])
properties_columns_to_be_removed
# Out:
# ['City of London',
#  'Inner London',
#  'Outer London',
#  'NORTH EAST',
#  'NORTH WEST',
#  'YORKS & THE HUMBER',
#  'EAST MIDLANDS',
#  'WEST MIDLANDS',
#  'EAST OF ENGLAND',
#  'LONDON',
#  'SOUTH EAST',
#  'SOUTH WEST',
#  'England']

# %%
properties = properties.drop(properties_columns_to_be_removed, axis=1)
properties. shape
# Out:
# (362, 33)

# %% [markdown]
# ##### 2.2.3. Transpose dataset

# %%
properties_transposed = properties.transpose()
properties_transposed.head()
# Out:
#                                     1                    2    \
# Unnamed: 0          1995-01-01 00:00:00  1995-02-01 00:00:00
# Barking & Dagenham                51870                52513
# Barnet                            98948                98848
# Bexley                            64956                64786
# Brent                             76880                77651
#
#                                     3                    4    \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# Barking & Dagenham                52701                54618
# Barnet                            97848                96273
# Bexley                            64366                64276
# Brent                             77644                78668
#
#                                     5                    6    \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# Barking & Dagenham                54524                55200
# ...

# %%
properties_transposed=properties_transposed.reset_index()
properties_transposed.head()
# Out:
#                 index                    1                    2  \
# 0          Unnamed: 0  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1  Barking & Dagenham                51870                52513
# 2              Barnet                98948                98848
# 3              Bexley                64956                64786
# 4               Brent                76880                77651
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1                52701                54618                54524
# 2                97848                96273                95737
# 3                64366                64276                63995
# 4                77644                78668                79464
#
#                      6                    7                    8  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00
# ...

# %%
# Renaming headers as per first rwo:
properties_transposed.columns = properties_transposed.iloc[0]
properties_transposed = properties_transposed[1:]
properties_transposed.head()
# Out:
# 0          Unnamed: 0 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1  Barking & Dagenham               51870               52513
# 2              Barnet               98948               98848
# 3              Bexley               64956               64786
# 4               Brent               76880               77651
# 5             Bromley               83082               83068
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1               52701               54618               54524
# 2               97848               96273               95737
# 3               64366               64276               63995
# 4               77644               78668               79464
# 5               82856               82525               82951
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  \
# 1               55200               53569               53691
# 2               95577               96992               97968
# ...

# %% [markdown]
# #### 2.3. Cleaning the data (part 2)
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
properties_transposed.rename(columns={'Unnamed: 0': 'London Borough'}, inplace=True)
properties_transposed.head()
# Out:
# 0      London Borough 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1  Barking & Dagenham               51870               52513
# 2              Barnet               98948               98848
# 3              Bexley               64956               64786
# 4               Brent               76880               77651
# 5             Bromley               83082               83068
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1               52701               54618               54524
# 2               97848               96273               95737
# 3               64366               64276               63995
# 4               77644               78668               79464
# 5               82856               82525               82951
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  \
# 1               55200               53569               53691
# 2               95577               96992               97968
# ...

# %%
# Exclude time from headers:
properties_transposed.columns = [col.date() if isinstance(col, pd.Timestamp) else col for col in properties_transposed.columns]
properties_transposed.head()
# Out:
#        London Borough 1995-01-01 1995-02-01 1995-03-01 1995-04-01 1995-05-01  \
# 1  Barking & Dagenham      51870      52513      52701      54618      54524
# 2              Barnet      98948      98848      97848      96273      95737
# 3              Bexley      64956      64786      64366      64276      63995
# 4               Brent      76880      77651      77644      78668      79464
# 5             Bromley      83082      83068      82856      82525      82951
#
#   1995-06-01 1995-07-01 1995-08-01 1995-09-01  ... 2024-05-01 2024-06-01  \
# 1      55200      53569      53691      52909  ...     341750     335531
# 2      95577      96992      97968      98936  ...     616958     619994
# 3      64251      63721      64431      64508  ...     395593     399795
# 4      80118      79920      79295      79557  ...     540597     564733
# 5      83806      84330      83471      82847  ...     487684     492664
#
# ...

# %% [markdown]
# #### 2.4. Transforming the data
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
properties_transposed_melted = properties_transposed.melt(id_vars="London Borough", var_name="Month", value_name="Price" )
properties_transposed_melted
# Out:
#            London Borough       Month   Price
# 0      Barking & Dagenham  1995-01-01   51870
# 1                  Barnet  1995-01-01   98948
# 2                  Bexley  1995-01-01   64956
# 3                   Brent  1995-01-01   76880
# 4                 Bromley  1995-01-01   83082
# ...                   ...         ...     ...
# 11579              Sutton  2025-02-01  445207
# 11580       Tower Hamlets  2025-02-01  502561
# 11581      Waltham Forest  2025-02-01  523121
# 11582          Wandsworth  2025-02-01  710541
# 11583         Westminster  2025-02-01  920645
#
# [11584 rows x 3 columns]

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
properties_transposed_melted["Month"] = pd.to_datetime(properties_transposed_melted["Month"])
properties_transposed_melted["Price"] = properties_transposed_melted["Price"].astype(float)
properties_transposed_melted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11584 entries, 0 to 11583
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   London Borough  11584 non-null  object
#  1   Month           11584 non-null  datetime64[ns]
#  2   Price           11584 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 271.6+ KB

# %% [markdown]
# #### 2.5. Cleaning the data (part 3)
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %% [markdown]
# **ALREADY DONE AT FIRST DATA CLEANING STEPS**

# %% [markdown]
# #### 2.6. Visualizing the data
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
# Magic command to display matplotlib plots inside Jupyter notebook:
# %matplotlib inline

# Particular borough:
barnet_selection = properties_transposed_melted["London Borough"] == "Barnet"
barnet_df = properties_transposed_melted[barnet_selection]
barnet_df
# Out:
#       London Borough      Month     Price
# 1             Barnet 1995-01-01   98948.0
# 33            Barnet 1995-02-01   98848.0
# 65            Barnet 1995-03-01   97848.0
# 97            Barnet 1995-04-01   96273.0
# 129           Barnet 1995-05-01   95737.0
# ...              ...        ...       ...
# 11425         Barnet 2024-10-01  626302.0
# 11457         Barnet 2024-11-01  627685.0
# 11489         Barnet 2024-12-01  622984.0
# 11521         Barnet 2025-01-01  610940.0
# 11553         Barnet 2025-02-01  602832.0
#
# [362 rows x 3 columns]

# %%
# Particular borough plot:
fig1, ax1 = plt.subplots()
ax1.plot(barnet_df["Month"], barnet_df["Price"])
plt.show()

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
# Creation of an additional column "Year":
properties_transposed_melted['Year'] = properties_transposed_melted['Month'].apply(lambda x: x.year)
properties_transposed_melted
# Out:
#            London Borough      Month     Price  Year
# 0      Barking & Dagenham 1995-01-01   51870.0  1995
# 1                  Barnet 1995-01-01   98948.0  1995
# 2                  Bexley 1995-01-01   64956.0  1995
# 3                   Brent 1995-01-01   76880.0  1995
# 4                 Bromley 1995-01-01   83082.0  1995
# ...                   ...        ...       ...   ...
# 11579              Sutton 2025-02-01  445207.0  2025
# 11580       Tower Hamlets 2025-02-01  502561.0  2025
# 11581      Waltham Forest 2025-02-01  523121.0  2025
# 11582          Wandsworth 2025-02-01  710541.0  2025
# 11583         Westminster 2025-02-01  920645.0  2025
#
# [11584 rows x 4 columns]

# %%
# Control of "Year" data type:
properties_transposed_melted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11584 entries, 0 to 11583
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   London Borough  11584 non-null  object
#  1   Month           11584 non-null  datetime64[ns]
#  2   Price           11584 non-null  float64
#  3   Year            11584 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 362.1+ KB

# %%
# Overall plot for all borough spanning all dates:
fig, ax = plt.subplots(figsize=(12, 6))
for borough, group in properties_transposed_melted.groupby('London Borough'):
    ax.plot(group['Month'], group['Price'], label=borough)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=4, fontsize='small')
plt.show()

# %% [markdown]
# ### 3. Modeling
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
# Function defnition for each borough compuation:
def greatest_increase(df, borough, year_start, year_end):

    span_condition = (df["London Borough"] == borough) & ((df["Year"] == year_start) | (df["Year"] == year_end))
    df_span = df[span_condition]

    df_span_mean_prices = df_span.groupby(["London Borough", "Year"]).agg({"Price":"mean"}).reset_index()
    
    price_start =df_span_mean_prices[df_span_mean_prices["Year"] == year_start]["Price"].values[0]
    price_end = df_span_mean_prices[df_span_mean_prices["Year"] == year_end]["Price"].values[0]
    ratio = round((price_end / price_start) * 100, 2)

    return ratio

# %%
# Empty dictionary to collect the increase ratio for each borough iteration:
increase_ratios = dict()

# Iteration through each borough:
for borough in properties_transposed_melted["London Borough"].unique():
    ratio_increase = greatest_increase(properties_transposed_melted, borough, 1998, 2018)
    increase_ratios[borough] = ratio_increase

# control:
print(increase_ratios)
# Out:
# {'Barking & Dagenham': 489.64, 'Barnet': 435.78, 'Bexley': 424.98, 'Brent': 489.55, 'Bromley': 409.48, 'Camden': 493.4, 'Croydon': 420.1, 'Ealing': 431.18, 'Enfield': 426.27, 'Greenwich': 476.36, 'Hackney': 619.83, 'Hammersmith & Fulham': 413.89, 'Haringey': 513.46, 'Harrow': 405.92, 'Havering': 432.59, 'Hillingdon': 420.03, 'Hounslow': 397.71, 'Islington': 484.19, 'Kensington & Chelsea': 508.22, 'Kingston upon Thames': 427.0, 'Lambeth': 495.82, 'Lewisham': 544.79, 'Merton': 474.52, 'Newham': 530.77, 'Redbridge': 447.02, 'Richmond upon Thames': 400.28, 'Southwark': 551.64, 'Sutton': 411.89, 'Tower Hamlets': 462.67, 'Waltham Forest': 583.51, 'Wandsworth': 475.76, 'Westminster': 535.27}

# %%
# Selection of the borough with maximum of increase ratio
greatest_increase_ratio = max(increase_ratios, key=increase_ratios.get)

# final answer and borough with the biggest increase ratio:
print(f"{greatest_increase_ratio} London Borough has witnessed the biggest in housing price" \
     f" with a {increase_ratios[greatest_increase_ratio]}% increase.")
# Out:
# Hackney London Borough has witnessed the biggest in housing price with a 619.83% increase.

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
# **More than 600% increase in the most expensive borough of London!**
#
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!
